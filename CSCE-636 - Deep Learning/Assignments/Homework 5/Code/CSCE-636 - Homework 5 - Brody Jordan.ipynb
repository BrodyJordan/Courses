# %% [markdown]
# ---
#
# # Homework 5
#
# **Course:** CSCE-636-700
#
# **Instructor:** Dr. Anxiao Jiang
#
# **Author:** Brody Jordan (431005357)
#
# ---

# %% [markdown]
#  Check out the Jupyter notebooks for Chapter 10 at https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/chapter10_interpreting-what-convnets-learn.ipynb and Chapter 11 at https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/chapter11_image-segmentation.ipynb.
#
# ## Problem 1
#
# Try the code on "Visualizing intermediate activations". Show the visualization result on a randomly selected image from the dogs-vs-cats dataset.

# %% [markdown]
# ## Problem 2
#
# Try the code on "Visualizing convnet filters". Show the visualization result for a randomly selected filter.

# %% [markdown]
# ## Problem 3
#
# Try the code on "Visualizing heatmaps of class activation". Show the visualization result on a randomly selected image from the dogs-vs-cats dataset.

# %% [markdown]
# ## Problem 4
#
# Try the code on image segmentation. Show the segmentation result on a randomly selected image.
